# %% [markdown]
# # Run FunSearch on Bin Packing
# Five steps:
# 1. Implement 'LLM' interface.
# 2. Implement a 'SandBox' interface.
# 3. Prepare a 'specification'.
# 4. Prepare a dataset.
# 5. Start FunSearch.

# %% [markdown]
# ## Preparation: download the project file from github. And update system path.

# %%
# !git clone https://github.com/RayZhhh/funsearch.git

import sys

sys.path.append('/content/funsearch/')
# Out:
# fatal: destination path 'funsearch' already exists and is not an empty directory.

# %% [markdown]
# ## 1. Implement LLM interface
# Set the API's IP address according to your API provider (See line 65 in the following code).
# ```python
# conn = http.client.HTTPSConnection("api.chatanywhere.com.cn")
# ```
# You should prepare a 'key' for the LLM API. And fill them in the header (See line 76-80 in the following code).
# ```python
# headers = {
#     'Authorization': 'Bearer [put your key here, the key may start with "sk-..."]',
#     'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
#     'Content-Type': 'application/json'
# }
# ```

# %%
import time
import json
import multiprocessing
from typing import Collection, Any
import http.client
from implementation import sampler


def _trim_preface_of_body(sample: str) -> str:
    """Trim the redundant descriptions/symbols/'def' declaration before the function body.
    Please see my comments in sampler.LLM (in sampler.py).
    Since the LLM used in this file is not a pure code completion LLM, this trim function is required.

    -Example sample (function & description generated by LLM):
    -------------------------------------
    This is the optimized function ...
    def priority_v2(...) -> ...:
        return ...
    This function aims to ...
    -------------------------------------
    -This function removes the description above the function's signature, and the function's signature.
    -The indent of the code is preserved.
    -Return of this function:
    -------------------------------------
        return ...
    This function aims to ...
    -------------------------------------
    """
    lines = sample.splitlines()
    func_body_lineno = 0
    find_def_declaration = False
    for lineno, line in enumerate(lines):
        # find the first 'def' statement in the given code
        if line[:3] == 'def':
            func_body_lineno = lineno
            find_def_declaration = True
            break
    if find_def_declaration:
        code = ''
        for line in lines[func_body_lineno + 1:]:
            code += line + '\n'
        return code
    return sample


class LLMAPI(sampler.LLM):
    """Language model that predicts continuation of provided source code.
    """

    def __init__(self, samples_per_prompt: int, trim=True):
        super().__init__(samples_per_prompt)
        additional_prompt = ('Complete a different and more complex Python function. '
                             'Be creative and you can insert multiple if-else and for-loop in the code logic.'
                             'Only output the Python code, no descriptions.')
        self._additional_prompt = additional_prompt
        self._trim = trim

    def draw_samples(self, prompt: str) -> Collection[str]:
        """Returns multiple predicted continuations of `prompt`."""
        return [self._draw_sample(prompt) for _ in range(self._samples_per_prompt)]

    def _draw_sample(self, content: str) -> str:
        prompt = '\n'.join([content, self._additional_prompt])
        while True:
            try:
                conn = http.client.HTTPSConnection("api.bltcy.ai")
                payload = json.dumps({
                    "max_tokens": 512,
                    "model": "gpt-4o",
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ]
                })
                headers = {
                    'Authorization': 'Bearer sk-2HpBd9fETREDd1H2730f4e03368c48D7A836B13c86CeFa35',
                    'User-Agent': 'Apifox/1.0.0 (https://apifox.com)',
                    'Content-Type': 'application/json'
                }
                conn.request("POST", "/v1/chat/completions", payload, headers)
                res = conn.getresponse()
                data = res.read().decode("utf-8")
                data = json.loads(data)
                response = data['choices'][0]['message']['content']
                # trim function
                if self._trim:
                    response = _trim_preface_of_body(response)
                return response
            except Exception:
                print('retry')
                time.sleep(2)
                continue

# %% [markdown]
# ## 2. Implement a 'SandBox' interface

# %%
from implementation import evaluator
from implementation import evaluator_accelerate


class Sandbox(evaluator.Sandbox):
    """Sandbox for executing generated code. Implemented by RZ.

    RZ: Sandbox returns the 'score' of the program and:
    1) avoids the generated code to be harmful (accessing the internet, take up too much RAM).
    2) stops the execution of the code in time (avoid endless loop).
    """

    def __init__(self, verbose=False, numba_accelerate=True):
        """
        Args:
            verbose         : Print evaluate information.
            numba_accelerate: Use numba to accelerate the evaluation. It should be noted that not all numpy functions
                              support numba acceleration, such as np.piecewise().
        """
        self._verbose = verbose
        self._numba_accelerate = numba_accelerate

    def run(
            self,
            program: str,
            function_to_run: str,  # RZ: refers to the name of the function to run (e.g., 'evaluate')
            function_to_evolve: str,  # RZ: accelerate the code by decorating @numba.jit() on function_to_evolve.
            inputs: Any,  # refers to the dataset
            test_input: str,  # refers to the current instance
            timeout_seconds: int,
            **kwargs  # RZ: add this
    ) -> tuple[Any, bool]:
        """Returns `function_to_run(test_input)` and whether execution succeeded.

        RZ: If the generated code (generated by LLM) is executed successfully,
        the output of this function is the score of a given program.
        RZ: PLEASE NOTE THAT this SandBox is only designed for bin-packing problem.
        """
        dataset = inputs[test_input]
        try:
            result_queue = multiprocessing.Queue()
            process = multiprocessing.Process(
                target=self._compile_and_run_function,
                args=(program, function_to_run, function_to_evolve, dataset, self._numba_accelerate, result_queue)
            )
            process.start()
            process.join(timeout=timeout_seconds)
            if process.is_alive():
                # if the process is not finished in time, we consider the program illegal
                process.terminate()
                process.join()
                results = None, False
            else:
                if not result_queue.empty():
                    results = result_queue.get_nowait()
                else:
                    results = None, False

            return results
        except:
            return None, False

    def _compile_and_run_function(self, program, function_to_run, function_to_evolve, dataset, numba_accelerate,
                                  result_queue):
        try:
            # optimize the code (decorate function_to_run with @numba.jit())
            if numba_accelerate:
                program = evaluator_accelerate.add_numba_decorator(
                    program=program,
                    function_to_evolve=function_to_evolve
                )
            # compile the program, and maps the global func/var/class name to its address
            all_globals_namespace = {}
            # execute the program, map func/var/class to global namespace
            exec(program, all_globals_namespace)
            # get the pointer of 'function_to_run'
            function_to_run = all_globals_namespace[function_to_run]
            # return the execution results
            results = function_to_run(dataset)
            # the results must be int or float
            if not isinstance(results, (int, float)):
                result_queue.put((None, False))
                return
            result_queue.put((results, True))
        except Exception:
            # if raise any exception, we assume the execution failed
            result_queue.put((None, False))

# %% [markdown]
# ## 3. Prepare a 'specification'

# %%
specification = r'''
import numpy as np


def get_valid_bin_indices(item: float, bins: np.ndarray) -> np.ndarray:
    """Returns indices of bins in which item can fit."""
    return np.nonzero((bins - item) >= 0)[0]


def online_binpack(
        items: tuple[float, ...], bins: np.ndarray
) -> tuple[list[list[float, ...], ...], np.ndarray]:
    """Performs online binpacking of `items` into `bins`."""
    # Track which items are added to each bin.
    packing = [[] for _ in bins]
    # Add items to bins.
    for item in items:
        # Extract bins that have sufficient space to fit item.
        valid_bin_indices = get_valid_bin_indices(item, bins)
        # Score each bin based on heuristic.
        priorities = priority(item, bins[valid_bin_indices])
        # Add item to bin with highest priority.
        best_bin = valid_bin_indices[np.argmax(priorities)]
        bins[best_bin] -= item
        packing[best_bin].append(item)
    # Remove unused bins from packing.
    packing = [bin_items for bin_items in packing if bin_items]
    return packing, bins


@funsearch.run
def evaluate(instances: dict) -> float:
    """Evaluate heuristic function on a set of online binpacking instances."""
    # List storing number of bins used for each instance.
    num_bins = []
    # Perform online binpacking for each instance.
    for name in instances:
        instance = instances[name]
        capacity = instance['capacity']
        items = instance['items']
        # Create num_items bins so there will always be space for all items,
        # regardless of packing order. Array has shape (num_items,).
        bins = np.array([capacity for _ in range(instance['num_items'])])
        # Pack items into bins and return remaining capacity in bins_packed, which
        # has shape (num_items,).
        _, bins_packed = online_binpack(items, bins)
        # If remaining capacity in a bin is equal to initial capacity, then it is
        # unused. Count number of used bins.
        num_bins.append((bins_packed != capacity).sum())
    # Score of heuristic function is negative of average number of bins used
    # across instances (as we want to minimize number of bins).
    return -np.mean(num_bins)


@funsearch.evolve
def priority(item: float, bins: np.ndarray) -> np.ndarray:
    """Returns priority with which we want to add item to each bin.

    Args:
        item: Size of item to be added to the bin.
        bins: Array of capacities for each bin.

    Return:
        Array of same size as bins with priority score of each bin.
    """
    ratios = item / bins
    log_ratios = np.log(ratios)
    priorities = -log_ratios
    return priorities
'''

# %% [markdown]
# ## 4. Prepare a dataset

# %%
import bin_packing_utils

bin_packing_or3 = {'OR3': bin_packing_utils.datasets['OR3']}

# %% [markdown]
# ## 5. Start FunSearch
# Please note that in jupyter notebook the following code will fail. This is because juypter does not support multiprocessing. Colab backend supports multiprocessing.

# %%
from implementation import funsearch
from implementation import config

# It should be noted that the if __name__ == '__main__' is required.
# Because the inner code uses multiprocess evaluation.
if __name__ == '__main__':
    class_config = config.ClassConfig(llm_class=LLMAPI, sandbox_class=Sandbox)
    config = config.Config(samples_per_prompt=4, evaluate_timeout_seconds=30)
    global_max_sample_num = 10  # if it is set to None, funsearch will execute an endless loop
    funsearch.main(
        specification=specification,
        inputs=bin_packing_or3,
        config=config,
        max_sample_nums=global_max_sample_num,
        class_config=class_config,
        log_dir='../logs/funsearch_llm_api'
    )
# Out:
# INFO:absl:Best score of island 0 increased to -500.0
# INFO:absl:Best score of island 1 increased to -500.0
# INFO:absl:Best score of island 2 increased to -500.0
# INFO:absl:Best score of island 3 increased to -500.0
# INFO:absl:Best score of island 4 increased to -500.0
# INFO:absl:Best score of island 5 increased to -500.0
# INFO:absl:Best score of island 6 increased to -500.0
# INFO:absl:Best score of island 7 increased to -500.0
# INFO:absl:Best score of island 8 increased to -500.0
# INFO:absl:Best score of island 9 increased to -500.0
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     ratios = item / bins
#     log_ratios = np.log(ratios)
#     priorities = -log_ratios
#     return priorities
# ------------------------------------------------------
# Score        : -500.0
# Sample time  : None
# Evaluate time: 1.2178723812103271
# Sample orders: None
# ======================================================
#
#
# 1
# 1
# 1
# 1
# INFO:absl:Best score of island 4 increased to -499.85
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0` with more sophisticated prioritization."""
#     n_bins = len(bins)
#     priorities = np.zeros(n_bins)
#
#     for i in range(n_bins):
#         remaining_capacity = bins[i] - item
#         if remaining_capacity < 0:
#             priorities[i] = np.inf  # Cannot fit, very low priority
#         else:
#             ratio = item / bins[i]
#             priority_score = 1 / (1 + np.exp(-5 * (ratio - 0.5)))  # S-shaped curve for more nuance
#
#             # Additional conditions to modify the priority score
#             if remaining_capacity < 0.1 * bins[i]:
#                 priority_score *= 1.5  # Encourage to fill bins closer to capacity
#             elif remaining_capacity > 0.7 * bins[i]:
#                 priority_score *= 0.75  # Discourage using bins with too much space
#
#             # Additional condition based on even-odd index
#             if i % 2 == 0:
#                 priority_score *= 1.1  # Favor even-indexed bins slightly
#
#             priorities[i] = -np.log(priority_score)  # Inversion to prioritize
#
#     return priorities
# ------------------------------------------------------
# Score        : -499.85
# Sample time  : 5.471690773963928
# Evaluate time: 1.5418798923492432
# Sample orders: 2
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0`."""
#     priorities = np.zeros_like(bins, dtype=float)
#
#     for i, bin in enumerate(bins):
#         if bin <= 0:
#             priorities[i] = -np.inf  # Handle edge case for non-positive bin capacity
#         else:
#             ratio = item / bin
#             if ratio < 0.25:
#                 priorities[i] = 10 - np.log(1 + ratio)
#             elif 0.25 <= ratio < 0.5:
#                 priorities[i] = 5 / (ratio + 0.1)
#             elif 0.5 <= ratio < 0.75:
#                 priorities[i] = np.exp(-ratio) + 3
#             else:
#                 priorities[i] = 1 / ratio
#
#         # Extra adjustment for bins below 0.1 capacity
#         if bin < 0.1:
#             priorities[i] *= 1.5
#
#     # Normalize the priorities to range [0, 1] for easier comparison
#     max_priority = np.max(priorities)
#     if max_priority > 0:
#         priorities = priorities / max_priority
#
#     return priorities
# ------------------------------------------------------
# Score        : None
# Sample time  : 5.471690773963928
# Evaluate time: 1.2024352550506592
# Sample orders: 3
# ======================================================
# INFO:absl:Best score of island 4 increased to -212.05
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0`."""
#     # Initialize priorities with empty list
#     priorities = []
#
#     for bin_capacity in bins:
#         if bin_capacity <= 0:
#             # Assign a very low priority if bin capacity is not positive
#             priority = float('inf')
#         else:
#             # Calculate the priority as a complex function of item and bin
#             ratio = item / bin_capacity
#             if ratio < 0.5:
#                 # Low ratio favorability
#                 priority = -np.log(1 + ratio)
#             elif 0.5 <= ratio < 1:
#                 # Medium ratio favorability
#                 priority = np.square(1 - ratio)
#             else:
#                 # High ratio favorability
#                 priority = np.exp(ratio - 1)
#
#         # Incorporate variance and skew into decision-making
#         variance_factor = np.var(bins) / (1 + abs(item - bin_capacity))
#         skew = (3 * (np.mean(bins) - np.median(bins)) / np.std(bins)) if np.std(bins) != 0 else 0
#         priority += variance_factor + skew
#
#         priorities.append(priority)
#
#     return np.array(priorities)
# ------------------------------------------------------
# Score        : -212.05
# Sample time  : 5.471690773963928
# Evaluate time: 22.56011176109314
# Sample orders: 4
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0`.
#
#     This function calculates a more complex priority score by considering
#     both the remaining capacity of each bin and how well the item fits
#     within each bin's capacity.
#     """
#     def calculate_fit_score(item, remaining_capacity):
#         if item > remaining_capacity:
#             return np.inf
#         return remaining_capacity - item
#
#     def calculate_ratio_penalty(item, bin_capacity):
#         if item > bin_capacity:
#             return np.inf
#         return np.log(bin_capacity / item)
#
#     priorities = np.empty_like(bins)
#
#     for idx, bin_capacity in enumerate(bins):
#         remaining_capacity = bin_capacity
#
#         fit_score = calculate_fit_score(item, remaining_capacity)
#         ratio_penalty = calculate_ratio_penalty(item, bin_capacity)
#
#         if fit_score == np.inf or ratio_penalty == np.inf:
#             priorities[idx] = np.inf
#         else:
#             if fit_score < 0:
#                 priority = ratio_penalty - 2 * fit_score
#             elif ratio_penalty < 0:
#                 priority = ratio_penalty + 0.5 * fit_score
#             else:
#                 priority = (ratio_penalty + fit_score) / 2
#
#             priorities[idx] = priority
#
#     return priorities
# ------------------------------------------------------
# Score        : -500.0
# Sample time  : 5.471690773963928
# Evaluate time: 1.2978839874267578
# Sample orders: 5
# ======================================================
#
#
# 1
# 1
# 1
# 1
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0` with more complex logic."""
#     if item <= 0:
#         raise ValueError("Item size must be positive.")
#
#     priorities = np.zeros_like(bins, dtype=float)
#
#     for i in range(len(bins)):
#         if bins[i] <= 0:
#             priorities[i] = float('inf')  # Infinite priority for full bins
#         else:
#             ratio = item / bins[i]
#             if ratio < 0.5:
#                 priorities[i] = 1.0 / (1 + np.exp(-10 * (ratio - 0.25)))
#             elif 0.5 <= ratio < 0.9:
#                 priorities[i] = 2 * (1 / (1 + np.exp(-5 * (ratio - 0.7)))) + 1
#             else:
#                 if bins[i] - item >= 0:
#                     priorities[i] = -np.log1p(ratio - 0.9)
#                 else:
#                     priorities[i] = float('inf')  # Restrict overflow
#
#     # Normalize priorities to ensure they sum to 1
#     total_priority = np.sum(priorities)
#     if total_priority > 0:
#         priorities /= total_priority
#     else:
#         # In case of all full bins, distribute equally
#         priorities.fill(1.0 / len(priorities))
#
#     return priorities
# ------------------------------------------------------
# Score        : None
# Sample time  : 5.736076176166534
# Evaluate time: 0.8783516883850098
# Sample orders: 6
# ======================================================
# INFO:absl:Best score of island 7 increased to -307.35
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0` that incorporates additional heuristics."""
#     if item <= 0:
#         return np.zeros_like(bins)
#     priorities = np.zeros_like(bins)
#
#     # Adjust by how close the item size is to the bin capacity
#     for i, bin_capacity in enumerate(bins):
#         if bin_capacity <= 0:
#             priorities[i] = float('inf')
#             continue
#
#         ratio = item / bin_capacity
#         if ratio > 1:
#             priorities[i] = float('inf')
#         else:
#             priorities[i] = 1 / (1 + ratio)  # Favor bins that suit the item closely
#
#     # Weight heavily towards bins that leave least empty space
#     bins_with_space = np.copy(bins)
#     bins_with_space -= item
#
#     if np.all(bins_with_space < 0):
#         return np.full_like(bins, float('inf'))  # If all bins overflow, no valid choice
#
#     for i, remaining_space in enumerate(bins_with_space):
#         if remaining_space >= 0:
#             if remaining_space == 0:
#                 priorities[i] -= 10  # Optimal fit, highest priority
#             else:
#                 priorities[i] += np.log(1 + remaining_space)
#
#     # Sort by priority favoring less empty space
#     sorted_indices = np.argsort(priorities)
#     return priorities[sorted_indices]
# ------------------------------------------------------
# Score        : -307.35
# Sample time  : 5.736076176166534
# Evaluate time: 4.2829155921936035
# Sample orders: 7
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0` with more complex logic"""
#     priorities = np.zeros_like(bins)
#
#     # Avoid division by zero
#     bins = np.where(bins == 0, np.nan, bins)
#
#     for i, bin_capacity in enumerate(bins):
#         # If the item fits exactly, give it highest priority
#         if item == bin_capacity:
#             priorities[i] = float('inf')
#         elif item < bin_capacity:
#             # Check how much space would be left - prioritize less remaining space
#             remaining_space = bin_capacity - item
#             if remaining_space <= 0.1 * bin_capacity:
#                 priorities[i] = 10
#             elif remaining_space <= 0.25 * bin_capacity:
#                 priorities[i] = 5
#             else:
#                 priorities[i] = 1 / (1 + np.exp(-remaining_space))  # Sigmoid decay
#         else:
#             # If item doesn't fit, assign zero priority
#             priorities[i] = 0
#
#         # Additional factor: penalize heavier usage of the bin
#         if bin_capacity != 0:
#             usage_ratio = (bin_capacity - item) / bin_capacity
#             if usage_ratio < 0.5:
#                 priorities[i] *= 0.5
#
#     # Normalize priorities to avoid NaNs from infinities or zeros
#     priorities = np.nan_to_num(priorities, nan=0.0, posinf=1.0, neginf=0.0)
#     max_priority = np.max(priorities)
#     if max_priority > 0:
#         priorities = priorities / max_priority
#
#     return priorities
# ------------------------------------------------------
# Score        : None
# Sample time  : 5.736076176166534
# Evaluate time: 2.867985486984253
# Sample orders: 8
# ======================================================
# INFO:absl:Best score of island 7 increased to -220.2
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0`."""
#     priorities = np.zeros_like(bins)
#     for i in range(len(bins)):
#         if item > bins[i]:
#             priorities[i] = float('inf')  # Can't fit in this bin
#         else:
#             fill_ratio = item / bins[i]
#             if fill_ratio < 0.25:
#                 priorities[i] = 1 / fill_ratio  # Prefer bins where item fits comfortably
#             elif fill_ratio < 0.75:
#                 priorities[i] = np.exp(-fill_ratio)  # Bin is moderately filled after item
#             else:
#                 priorities[i] = (1 - fill_ratio) / fill_ratio  # Bin nearly full, prioritize less
#     # Adding variability based on bin size
#     max_bin = np.max(bins)
#     for i in range(len(bins)):
#         if bins[i] == max_bin:
#             priorities[i] *= 0.5  # Prefer smaller bins to start filling them
#         elif bins[i] < max_bin * 0.5:
#             priorities[i] *= 1.5  # Higher priority for smaller bins
#
#     return priorities
# ------------------------------------------------------
# Score        : -220.2
# Sample time  : 5.736076176166534
# Evaluate time: 2.0555551052093506
# Sample orders: 9
# ======================================================
#
#
# 1
# 1
# 1
# 1
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0`."""
#     priorities = np.zeros_like(bins)
#     for i in range(len(bins)):
#         if bins[i] <= 0:
#             priorities[i] = np.inf  # Assign very high priority to an invalid bin
#         else:
#             ratio = item / bins[i]
#             if ratio > 1.0:
#                 priorities[i] = np.inf  # Item won't fit, max priority
#             else:
#                 adjusted_ratio = ratio**2 if ratio >= 0.5 else ratio**3
#                 log_adjusted_ratio = np.log(adjusted_ratio + 1e-9)
#
#                 if adjusted_ratio > 0.1:
#                     priorities[i] = -log_adjusted_ratio * 1.5
#                 else:
#                     priorities[i] = -log_adjusted_ratio * 0.5
#
#     # Handling the case where all priorities may be infinity
#     if np.all(priorities == np.inf):
#         weights = np.array([1 / (bin + 1e-9) for bin in bins])
#         weights = weights / weights.sum()  # Normalize the weights
#         priorities = weights  # Use weights as priorities
#
#     return priorities
# ------------------------------------------------------
# Score        : None
# Sample time  : 6.212865650653839
# Evaluate time: 1.173661708831787
# Sample orders: 10
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0` with more complex logic."""
#     priorities = np.zeros_like(bins)
#
#     for i in range(len(bins)):
#         capacity = bins[i]
#
#         # If the bin is full, assign it a very low priority
#         if capacity == 0:
#             priorities[i] = float('inf')
#             continue
#
#         # Calculate the space available after adding the item
#         space_left = capacity - item
#
#         # Prioritize bins based on how close they are to being perfectly filled
#         if space_left >= 0:
#             priorities[i] = space_left + (1 / (capacity + 1))
#         else:
#             # If item doesn't fit, give a higher penalty
#             priorities[i] = float('inf') - space_left
#
#         # Apply a nonlinear penalty for very small or very large bins
#         if capacity < item / 2:
#             priorities[i] += np.exp(item - capacity)
#         elif capacity > 2 * item:
#             priorities[i] *= np.log10(capacity + 1)
#
#         # Add some random factor for similar priorities to break ties
#         priorities[i] += np.random.uniform(0, 0.01)
#
#     return priorities
# ------------------------------------------------------
# Score        : -500.0
# Sample time  : 6.212865650653839
# Evaluate time: 1.780268907546997
# Sample orders: 11
# ======================================================
#
#
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0` with a focus on item-to-bin fit, bin capacity,
#     and penalizing overfilling.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of current usage for each bin.
#         capacity: Maximum capacity for each bin.
#
#     Return:
#         Array of same size as bins with priority score for each bin.
#     """
#     priorities = np.zeros_like(bins)
#
#     for i, usage in enumerate(bins):
#         potential_usage = usage + item
#         if potential_usage > capacity:
#             # Penalty for overfilling
#             priorities[i] = -np.inf
#         else:
#             # Calculate fit ratio
#             ratio = item / (capacity - usage) if (capacity - usage) != 0 else np.inf
#
#             # Logarithmically scale and inversely prioritize higher ratio
#             priorities[i] = -np.log(ratio)
#
#             # Adding small penalty to avoid filling bins too close to capacity
#             if capacity - potential_usage < capacity * 0.1:
#                 priorities[i] -= 5
#
#     # Normalize priorities to keep them in a manageable range
#     min_val = np.min(priorities[priorities > -np.inf])
#     if min_val == -np.inf:
#         min_val = 0
#     priorities = (priorities - min_val) / (np.max(priorities) - min_val + 1e-10)
#
#     return priorities
# ------------------------------------------------------
# Score        : None
# Sample time  : 6.212865650653839
# Evaluate time: 1.1470506191253662
# Sample orders: 12
# ======================================================
# INFO:absl:Best score of island 1 increased to -211.75
# ================= Evaluated Function =================
# def priority(item: float, bins: np.ndarray) -> np.ndarray:
#     """Returns priority with which we want to add item to each bin.
#
#     Args:
#         item: Size of item to be added to the bin.
#         bins: Array of capacities for each bin.
#
#     Return:
#         Array of same size as bins with priority score of each bin.
#     """
#     """Improved version of `priority_v0` that includes multiple factors in determining priority."""
#
#     # Initialize an array to store the priority scores
#     priorities = np.zeros_like(bins)
#
#     # Iterate over each bin to calculate priority
#     for i, bin_capacity in enumerate(bins):
#         # Calculate the ratio
#         ratio = item / bin_capacity
#
#         # Different priority value based on ratio range
#         if 0 < ratio < 0.5:
#             priority = 1 / (1 + ratio)
#         elif 0.5 <= ratio < 0.9:
#             priority = 2 / (1 + np.log1p(ratio))
#         elif 0.9 <= ratio < 1.5:
#             priority = 5 - ratio ** 2
#         else:
#             priority = -np.log(np.abs(ratio - 1.5) + 1)
#
#         # Calculate penalty factor for bins with smaller sizes
#         penalty_factor = 1.0
#         if bin_capacity < item:
#             penalty_factor = 2.0
#         elif bin_capacity < 1.5 * item:
#             penalty_factor = 1.5
#
#         # Apply the penalty factor
#         priority *= penalty_factor
#
#         # Ensure priority is non-negative
#         priorities[i] = max(priority, 0)
#
#     return priorities
# ------------------------------------------------------
# Score        : -211.75
# Sample time  : 6.212865650653839
# Evaluate time: 1.4921305179595947
# Sample orders: 13
# ======================================================

# %%
from openai import OpenAI
API_KEY = 'sk-2HpBd9fETREDd1H2730f4e03368c48D7A836B13c86CeFa35'
BASE_URL = 'https://api.bltcy.ai/v1'

client = OpenAI(api_key=API_KEY, base_url=BASE_URL)

message = [
    {'role': 'user', 'content': 'Hello!'}
]

response = client.chat.completions.create(
    model='gpt-4o',
    messages=message,
    stream=False,
)

print(response.choices[0].message.content)
# Out:
# INFO:httpx:HTTP Request: POST https://api.bltcy.ai/v1/chat/completions "HTTP/1.1 200 OK"
# Hello! How can I assist you today?
